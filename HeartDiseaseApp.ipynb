# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\91997\Downloads\heart.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.size
# Out:
# 4228

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
#setting a grey background
sns.set_style("darkgrid")
#creating subplots with 10*10 fig. size
fig,axs=plt.subplots(2,2,figsize=(10,10))
#plotting the subplot with numerical variables
sns.histplot(data=df,x="age",kde=True,color="red" ,ax=axs[0,0])
sns.histplot(data=df,x="sex",kde=True,color="blue",ax=axs[0,1])
sns.histplot(data=df,x="cp",kde=True,color="gold",ax=axs[1,0])
sns.histplot(data=df,x="trestbps",kde=True,color="khaki",ax=axs[1,1])
plt.show()

# %%
sns.set_style("darkgrid")
#creating subplots with 10*10 fig. size
fig,axs=plt.subplots(2,2,figsize=(10,10))
sns.histplot(data=df,x="chol",kde=True,color="green",ax=axs[0,0])
sns.histplot(data=df,x="fbs",kde=True,color="gold",ax=axs[0,1])
sns.histplot(data=df,x="restecg",kde=True,color="yellow",ax=axs[1,0])
sns.histplot(data=df,x="thalach",kde=True,color="khaki",ax=axs[1,1])
plt.show()

# %%
sns.set_style("darkgrid")
#creating subplots with 10*10 fig. size
fig,axs=plt.subplots(3,2,figsize=(10,10))
sns.histplot(data=df,x="exang",kde=True,color="yellow",ax=axs[0,1])
sns.histplot(data=df,x="oldpeak",kde=True,color="gold",ax=axs[1,0])
sns.histplot(data=df,x="slope",kde=True,color="khaki",ax=axs[1,1])
sns.histplot(data=df,x="ca",kde=True,color="green",ax=axs[0,0])
sns.histplot(data=df,x="thal",kde=True,color="red",ax=axs[2,0])
sns.histplot(data=df,x="target",kde=True,color="olive",ax=axs[2,1])
# Out:
# <Axes: xlabel='target', ylabel='Count'>

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['age'])
plt.title("target vs age")
# Out:
# Text(0.5, 1.0, 'target vs age')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['sex'])
plt.title("target vs sex")
# Out:
# Text(0.5, 1.0, 'target vs sex')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['cp'])
plt.title("target vs cp")
# Out:
# Text(0.5, 1.0, 'target vs cp')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['trestbps'])
plt.title("target vs trestbps")
# Out:
# Text(0.5, 1.0, 'target vs trestbps')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['chol'])
plt.title("target vs chol ")
# Out:
# Text(0.5, 1.0, 'target vs chol ')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['fbs'])
plt.title("target vs fbs")
# Out:
# Text(0.5, 1.0, 'target vs fbs')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['restecg'])
plt.title("target vs restecg")
# Out:
# Text(0.5, 1.0, 'target vs restecg')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['thalach'])
plt.title("target vs thalach")
# Out:
# Text(0.5, 1.0, 'target vs thalach')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['exang'])
plt.title("target vs exang")
# Out:
# Text(0.5, 1.0, 'target vs exang')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['slope'])
plt.title("target vs slope")
# Out:
# Text(0.5, 1.0, 'target vs slope')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['ca'])
plt.title("target vs ca")
# Out:
# Text(0.5, 1.0, 'target vs ca')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['thal'])
plt.title("target vs thal")
# Out:
# Text(0.5, 1.0, 'target vs thal')

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=df['target'],y=df['oldpeak'])
plt.title("target vs oldpeak")
# Out:
# Text(0.5, 1.0, 'target vs oldpeak')

# %%
sns.boxplot(x=df['target'],y=df['age'])
plt.title('target vs age  ',color='red')
# Out:
# Text(0.5, 1.0, 'target vs age  ')

# %%
sns.boxplot(x=df['target'],y=df['sex'])
plt.title(' target vs sex',color='red')
# Out:
# Text(0.5, 1.0, ' target vs sex')

# %%
sns.boxplot(x=df['target'],y=df['cp'])
plt.title('target  vs cp',color='red')
# Out:
# Text(0.5, 1.0, 'target  vs cp')

# %%
sns.boxplot(x=df['target'],y=df['trestbps'])
plt.title(' target vs trestbps ',color='red')
# Out:
# Text(0.5, 1.0, ' target vs trestbps ')

# %%
sns.boxplot(x=df['target'],y=df['chol'])
plt.title('  target vs chol',color='red')
# Out:
# Text(0.5, 1.0, '  target vs chol')

# %%
sns.boxplot(x=df['target'],y=df['fbs'])
plt.title('  target vs fbs',color='red')
# Out:
# Text(0.5, 1.0, '  target vs fbs')

# %%
sns.boxplot(x=df['target'],y=df['restecg'])
plt.title('target  vs restecg',color='red')
# Out:
# Text(0.5, 1.0, 'target  vs restecg')

# %%
sns.boxplot(x=df['target'],y=df['thalach'])
plt.title('target  vs thalach',color='red')
# Out:
# Text(0.5, 1.0, 'target  vs thalach')

# %%
sns.boxplot(x=df['target'],y=df['exang'])
plt.title('target  vs exang',color='red')
# Out:
# Text(0.5, 1.0, 'target  vs exang')

# %%
sns.boxplot(x=df['target'],y=df['oldpeak'])
plt.title('target  vs oldpeak',color='red')
# Out:
# Text(0.5, 1.0, 'target  vs oldpeak')

# %%
sns.boxplot(x=df['target'],y=df['slope'])
plt.title('target  vs slope',color='red')
# Out:
# Text(0.5, 1.0, 'target  vs slope')

# %%
sns.boxplot(x=df['target'],y=df['ca'])
plt.title(' target vs ca',color='red')
# Out:
# Text(0.5, 1.0, ' target vs ca')

# %%
sns.boxplot(x=df['target'],y=df['thal'])
plt.title(' target vs thal',color='red')
# Out:
# Text(0.5, 1.0, ' target vs thal')

# %%
Q1=df.quantile(0.25) # taking lower quantile into Q2
Q3 =df.quantile(0.75) # taking upper quarantile to Q3
IQR = Q3 - Q1  #calculating inter quantile ramge
print(IQR)
# Out:
# age         13.00
# sex          1.00
# cp           2.00
# trestbps    20.00
# chol        63.75
# fbs          0.00
# restecg      1.00
# thalach     32.75
# exang        1.00
# oldpeak      1.60
# slope        1.00
# ca           1.00
# thal         1.00
# target       1.00
# dtype: float64

# %%
dfout=df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
dfout.shape
# Out:
# (228, 14)

# %%
sns.boxplot(x=dfout['age'])
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x=dfout['sex'])
# Out:
# <Axes: xlabel='sex'>

# %%
sns.boxplot(x=dfout['cp'])
# Out:
# <Axes: xlabel='cp'>

# %%
sns.boxplot(x=dfout['thalach'])
# Out:
# <Axes: xlabel='thalach'>

# %%
sns.boxplot(x=dfout['chol'])
# Out:
# <Axes: xlabel='chol'>

# %%
df_numeric=df.select_dtypes(include='number')

# %%
df_numeric.corr(method="spearman")#select the method as spearman
plt.figure(figsize=(10,10))
heatmap =sns.heatmap(df_numeric.corr(method="spearman").round(3),vmin=-1,vmax=1,annot=True)       #annot=True means writting the data value in each cell
font2={'family':'serif','color':'green','size':20}
plt.title("spearman rank corelation",font2)
plt.show()  #displaying heatmap

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#Model Building
X=df.drop(['target'],axis=1)
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
y=df['target'] #Depandent Varible to y
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 302, dtype: int64

# %%
#spilt X and Y into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)
X_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 137   62    1   1       128   208    1        0      140      0      0.0
# 106   69    1   3       160   234    1        0      131      0      0.1
# 285   46    1   0       140   311    0        1      120      1      1.8
# 44    39    1   2       140   321    0        0      182      0      0.0
# 139   64    1   0       128   263    0        1      105      1      0.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 252   62    0   0       138   294    1        1      106      0      1.9
# 193   60    1   0       145   282    0        0      142      1      2.8
# 117   56    1   3       120   193    0        0      162      0      1.9
# 47    47    1   2       138   257    0        0      156      0      0.0
# 173   58    1   2       132   224    0        0      173      0      3.2
#
#      slope  ca  thal
# 137      2   0     2
# 106      1   1     2
# 285      1   2     3
# ...

# %%
X_test
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 226   62    1   1       120   281    0        0      103      0      1.4
# 152   64    1   3       170   227    0        0      155      0      0.6
# 229   64    1   2       125   309    0        1      131      1      1.8
# 202   58    1   0       150   270    0        0      111      1      0.8
# 52    62    1   2       130   231    0        1      146      0      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 254   59    1   3       160   273    0        0      125      0      0.0
# 293   67    1   2       152   212    0        0      150      0      0.8
# 76    51    1   2       125   245    1        0      166      0      2.4
# 273   58    1   0       100   234    0        1      156      0      0.1
# 239   35    1   0       126   282    0        0      156      1      0.0
#
#      slope  ca  thal
# 226      1   1     3
# 152      1   0     3
# 229      1   0     3
# ...

# %%
y_train
# Out:
# 137    1
# 106    1
# 285    0
# 44     1
# 139    1
#       ..
# 252    0
# 193    0
# 117    1
# 47     1
# 173    0
# Name: target, Length: 211, dtype: int64

# %%
y_test
# Out:
# 226    0
# 152    1
# 229    0
# 202    0
# 52     1
#       ..
# 254    0
# 293    0
# 76     1
# 273    0
# 239    0
# Name: target, Length: 91, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
# fit scaler on training data
X_train = sc.fit_transform(X_train)
#tranform testing data
X_test = sc.fit_transform(X_test)
#x_scaled= (x - mesan(x)/std(x))

# %%
X_train
# Out:
# array([[ 0.84094222,  0.73494625,  0.01364906, ...,  0.9864245 ,
#         -0.69321675, -0.46555391],
#        [ 1.61578419,  0.73494625,  1.9336168 , ..., -0.65243825,
#          0.31553314, -0.46555391],
#        [-0.93012512,  0.73494625, -0.94633481, ..., -0.65243825,
#          1.32428303,  1.14480471],
#        ...,
#        [ 0.17679197,  0.73494625,  1.9336168 , ..., -0.65243825,
#         -0.69321675,  1.14480471],
#        [-0.81943341,  0.73494625,  0.97363293, ...,  0.9864245 ,
#         -0.69321675, -0.46555391],
#        [ 0.39817539,  0.73494625,  0.97363293, ...,  0.9864245 ,
#          1.32428303,  1.14480471]])

# %%
X_test
# Out:
# array([[ 0.83480196,  0.5646597 ,  0.08776912, ..., -0.63109353,
#          0.20219632,  1.06808266],
#        [ 1.05628003,  0.5646597 ,  2.0845166 , ..., -0.63109353,
#         -0.76621764,  1.06808266],
#        [ 1.05628003,  0.5646597 ,  1.08614286, ..., -0.63109353,
#         -0.76621764,  1.06808266],
#        ...,
#        [-0.38332743,  0.5646597 ,  1.08614286, ..., -0.63109353,
#         -0.76621764, -0.63710194],
#        [ 0.39184582,  0.5646597 , -0.91060462, ...,  0.96417067,
#          0.20219632,  1.06808266],
#        [-2.15515199,  0.5646597 , -0.91060462, ...,  0.96417067,
#         -0.76621764,  1.06808266]])

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lg = LogisticRegression()
lg.fit(X_train,y_train)
y_pred_lg = lg.predict(X_test)
accuracy_score(y_test,y_pred_lg)
precision_score
#calculate performance metrics
accuracy_lg = accuracy_score(y_test,y_pred_lg)
precision_lg = recall_score(y_test,y_pred_lg)
recall_lg = recall_score(y_test,y_pred_lg)
f1_lg = f1_score(y_test,y_pred_lg)
conf_matrix_lg = confusion_matrix(y_test,y_pred_lg)
class_report_lg = classification_report(y_test,y_pred_lg)
#print the performance metrics for the decision tree
print("LogisticRegression:")
print("Accuracy:", accuracy_lg)
print("Precision:", precision_lg)
print("Recall:", recall_lg)
print("F1 Score:", f1_lg)
print("Confusion Matrix:\n", conf_matrix_lg)
print("Classification Report:\n", class_report_lg)
# Out:
# LogisticRegression:
# Accuracy: 0.7912087912087912
# Precision: 0.8913043478260869
# Recall: 0.8913043478260869
# F1 Score: 0.8118811881188119
# Confusion Matrix:
#  [[31 14]
#  [ 5 41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.69      0.77        45
#            1       0.75      0.89      0.81        46
#
#     accuracy                           0.79        91
#    macro avg       0.80      0.79      0.79        91
# weighted avg       0.80      0.79      0.79        91

# %%
#initialize the decisiontree classifier
model_dt = DecisionTreeClassifier(random_state=42)
# train the model
model_dt.fit(X_train,y_train)
#make prediction
y_pred_dt = model_dt.predict(X_test)
#calculate performance metrics
accuracy_dt = accuracy_score(y_test,y_pred_dt)
precision_dt = recall_score(y_test,y_pred_dt)
recall_dt = recall_score(y_test,y_pred_dt)
f1_dt = f1_score(y_test,y_pred_dt)
conf_matrix_dt = confusion_matrix(y_test,y_pred_dt)
class_report_dt = classification_report(y_test,y_pred_dt)
#print the performance metrics for the decision tree
print("Decision Tree Classifier:")
print("Accuracy:", accuracy_dt)
print("Precision:", precision_dt)
print("Recall:", recall_dt)
print("F1 Score:", f1_dt)
print("Confusion Matrix:\n", conf_matrix_dt)
print("Classification Report:\n", class_report_dt)
# Out:
# Decision Tree Classifier:
# Accuracy: 0.7032967032967034
# Precision: 0.717391304347826
# Recall: 0.717391304347826
# F1 Score: 0.7096774193548387
# Confusion Matrix:
#  [[31 14]
#  [13 33]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.69      0.70        45
#            1       0.70      0.72      0.71        46
#
#     accuracy                           0.70        91
#    macro avg       0.70      0.70      0.70        91
# weighted avg       0.70      0.70      0.70        91

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize the Random Forest Classifier
model_rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
model_rf.fit(X_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(X_test)

# Calculate performance metrics
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)
conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
class_report_rf = classification_report(y_test, y_pred_rf)

# Print the performance metrics for Random Forest
print('Random Forest Metrics:')
print('Accuracy:', round(accuracy_rf, 2))
print('Precision:', round(precision_rf, 2))
print('Recall:', round(recall_rf, 2))
print('F1-Score:', round(f1_rf, 2))
print('Confusion Matrix:\n', conf_matrix_rf)
print('Classification Report:\n', class_report_rf)
# Out:
# Random Forest Metrics:
# Accuracy: 0.84
# Precision: 0.8
# Recall: 0.89
# F1-Score: 0.85
# Confusion Matrix:
#  [[35 10]
#  [ 5 41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82        45
#            1       0.80      0.89      0.85        46
#
#     accuracy                           0.84        91
#    macro avg       0.84      0.83      0.83        91
# weighted avg       0.84      0.84      0.83        91

# %%
from sklearn.svm import SVC
model_svm = SVC(random_state=42)
model_svm.fit(X_train,y_train)
y_pred_svm = model_svm.predict(X_test)
accuracy_svm = accuracy_score(y_test,y_pred_svm)
precision_svm = recall_score(y_test,y_pred_svm)
recall_svm = recall_score(y_test,y_pred_svm)
f1_svm = f1_score(y_test,y_pred_svm)
conf_matrix_svm = confusion_matrix(y_test,y_pred_svm)
class_report_svm = classification_report(y_test,y_pred_svm)
print("SVM Metrics:")
print("Accuracy:", accuracy_svm, 2)
print("Precision:", precision_svm, 2)
print("Recall:", recall_svm, 2)
print("F1 Score:", f1_svm, 2)
print("Confusion Matrix:\n", conf_matrix_svm)
print("Classification Report:\n", class_report_svm)
# Out:
# SVM Metrics:
# Accuracy: 0.8021978021978022 2
# Precision: 0.9130434782608695 2
# Recall: 0.9130434782608695 2
# F1 Score: 0.8235294117647058 2
# Confusion Matrix:
#  [[31 14]
#  [ 4 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.69      0.78        45
#            1       0.75      0.91      0.82        46
#
#     accuracy                           0.80        91
#    macro avg       0.82      0.80      0.80        91
# weighted avg       0.82      0.80      0.80        91

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score
#intialize the decision tree
model_dt = DecisionTreeClassifier(random_state=42)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
results_dt = cross_val_score(model_dt,X,y,cv=ssplit)
print('Decision Tree Cross-validation Results:',results_dt)
print('Mean Accuracy:', np.mean(results_dt))
# Out:
# Decision Tree Cross-validation Results: [0.79120879 0.72527473 0.71428571 0.74725275 0.78021978 0.74725275
#  0.73626374 0.79120879 0.82417582 0.72527473]
# Mean Accuracy: 0.7582417582417582

# %%
model_rf = RandomForestClassifier(random_state=42)
ssplit = ShuffleSplit(n_splits = 10,test_size = 0.30)

results_dt = cross_val_score(model_dt,X,y,cv = ssplit)
print('Random Forest Cross-Validation Results', results_dt)
print('Mean Accuracy: ', np.mean(results_dt))
# Out:
# Random Forest Cross-Validation Results [0.67032967 0.79120879 0.68131868 0.69230769 0.8021978  0.74725275
#  0.74725275 0.67032967 0.67032967 0.74725275]
# Mean Accuracy:  0.721978021978022

# %%
model_svm = SVC(random_state=42)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model_svm,X,y,cv=ssplit)#perform cross_validation
print(results)
print("/n Mean Cross validation Accuracy:",np.mean(results))
print('Mean Accuracy:',np.mean(results))
# Out:
# [0.64835165 0.59340659 0.56043956 0.69230769 0.67032967 0.71428571
#  0.64835165 0.6043956  0.68131868 0.52747253]
# /n Mean Cross validation Accuracy: 0.634065934065934
# Mean Accuracy: 0.634065934065934

# %%
import pickle
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier()
model_rf.fit(X_train,y_train)
with open('heart_model.pkl','wb') as file:
  pickle.dump(model_rf,file)
print('Model saved successfully')
# Out:
# Model saved successfully

# %%
with open('sch.pkl', 'wb') as scaler_file:
  pickle.dump(sc, scaler_file)

# %%
streamlit_code = """
import streamlit as st
import pandas as pd
import pickle

# Load the trained RandomForest model and scaler
with open('heart_model.pkl', 'rb') as file:
    model = pickle.load(file)
with open('sch.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

# Define the Streamlit app
st.title('Heart Disease Prediction App')

# Add the description
st.markdown(\"\"\"
Heart disease is a major cause of death around the world, but finding it early can save lives. This app helps you check your risk based on your health information, so you can take steps to stay healthy. It's easy to use, keeps your data safe, and gives you the information you need to make good choices about your heart health. Before that, please have a look on the symptoms of heart diseases.
\"\"\")
# Display the image
st.image("https://images.everydayhealth.com/images/seo-graphic-content-initiative/select-warning-signs-of-heart-disease.png?sfvrsn=32d246f4_3", caption='Symptoms of Heart Disease', use_column_width = True)

# User input for prediction
def user_input_features():
    st.sidebar.markdown("### Fill in the details to assess your risk of heart disease:")
    age = st.sidebar.number_input('Age', min_value=0, max_value=100, value=50)
    sex = st.sidebar.selectbox('Sex', (0, 1))
    cp = st.sidebar.selectbox('Chest Pain Type (cp)', (0, 1, 2, 3))
    trestbps = st.sidebar.number_input('Resting Blood Pressure (trestbps)', min_value=0, max_value=200, value=120)
    chol = st.sidebar.number_input('Serum Cholestoral (chol)', min_value=0, max_value=600, value=200)
    fbs = st.sidebar.selectbox('Fasting Blood Sugar (fbs > 120 mg/dl)', (0, 1))
    restecg = st.sidebar.selectbox('Resting Electrocardiographic Results (restecg)', (0, 1, 2))
    thalach = st.sidebar.number_input('Maximum Heart Rate Achieved (thalach)', min_value=0, max_value=250, value=150)
    exang = st.sidebar.selectbox('Exercise Induced Angina (exang)', (0, 1))
    oldpeak = st.sidebar.number_input('ST Depression Induced by Exercise (oldpeak)', min_value=0.0, max_value=10.0, value=1.0)
    slope = st.sidebar.selectbox('Slope of the Peak Exercise ST Segment (slope)', (0, 1, 2))
    ca = st.sidebar.number_input('Number of Major Vessels (ca)', min_value=0, max_value=4, value=0)
    thal = st.sidebar.selectbox('Thalassemia (thal)', (0, 1, 2, 3))
    
    data = {
        'age': age,
        'sex': sex,
        'cp': cp,
        'trestbps': trestbps,
        'chol': chol,
        'fbs': fbs,
        'restecg': restecg,
        'thalach': thalach,
        'exang': exang,
        'oldpeak': oldpeak,
        'slope': slope,
        'ca': ca,
        'thal': thal
    }
    
    features = pd.DataFrame(data, index=[0])
    return features

input_df = user_input_features()

# Display user input
st.subheader('User Input Parameters')
st.markdown("If details entered are correct. Press the Predict button")
st.write(input_df)

# Prediction
prediction = model.predict(input_df)
prediction_proba = model.predict_proba(input_df)


if st.button('Predict'):
    input_scaled = scaler.transform(input_df)  # Ensure the input is scaled as per training
    prediction = model.predict(input_scaled)
    prediction_proba = model.predict_proba(input_scaled)
    
    if prediction[0] == 1:
        st.write('<h3 style="color: red;">Heart Disease</h3>', unsafe_allow_html=True)
        st.image("https://previews.123rf.com/images/gloly67/gloly671807/gloly67180700005/104596443-cartoon-character-sadness-heart-with-nameplate-help-unhealthy-heart-concept-icon-design-vector.jpg", caption='You are at Risk', use_column_width = True)
    else:
        st.write('<h3 style="color: green;">No Heart Disease</h3>', unsafe_allow_html=True)
        st.image("https://static8.depositphotos.com/1400067/893/i/450/depositphotos_8936376-stock-photo-heart-mascot.jpg", caption='You are Safe', use_column_width = True)


# Display the prediction probability
st.subheader('Prediction Probability')
st.write(prediction_proba)
"""

# Saving to file
import os

file_path = os.path.join(os.getcwd(), 'heartpredictionapp.py')

try:
    with open(file_path, 'w') as file:
        file.write(streamlit_code)
    print(f"File '{file_path}' has been saved.")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# File 'C:\Users\91997\Downloads\heartpredictionapp.py' has been saved.
